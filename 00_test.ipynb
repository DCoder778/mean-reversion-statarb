# %%
print("Test")

# %% [markdown]
# I am testing a Statistical Arbitrage Mean-Reversion strategy I have implemented in order to generate pnL based on the spread between Mastercard and Visa. I have selected these 2 stocks for the pairs trading strategy. Both Mastercard and Visa run payment processing networks and are both exposed to the same economic drivers. Additionally, due to their similar business models and growth drivers they provide a very profitable pairs trading opportunity by effectively profiting from divergences in the spread of the two. I specifically selected these stocks as an ADF test suggests the spread is stationary and the stocks may be cointegrated.
